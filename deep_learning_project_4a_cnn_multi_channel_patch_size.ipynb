# %% [markdown]
# # Deep Learning Project 4a - Computer Vision Multi-Classification and                                                                  Multi-Layer Convolutional Neural Network Model
#
# Previously, pickle files were formatted datasets for training, development and testing on the CIFAR10 dataset (32 x 32 image size). The goal of this project is to train a convolutional neural network model using TensorFlow with an image pipeline, one(1) channel, five (5) layers [two(2) convoluational; three (3) fully connected], depth of 5, and 3 by 3 patch filter size.

# %%
# Import required modules
import os
import sys
import tarfile
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from six.moves import urllib
from tensorflow.python.framework import ops

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
batch_size = 128
image_height = 32
image_width = 32
num_channels = 3
num_targets = 10

# %%
image_vec_length = image_height*image_width*num_channels
record_length = 1 + image_vec_length

# %%
data_dir = 'temp_cifar'
if not os.path.exists(data_dir):
    print('Make temp directory at code root directory location')
    os.makedirs(data_dir)
cifar10_url = 'http://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz'
data_file = os.path.join(data_dir,'cifar-10-binary.tar.gz')
if not os.path.isfile(data_file):
    # Download cifar10 file
    filepath, _ = urllib.request.urlretrieve(cifar10_url, data_file)
    # Extract file
    tarfile.open(filepath, 'r:gz').extractall(data_dir)

# %%
crop_height = 24
crop_width = 24

def read_cifar_files(filename_queue, distort_images =True):
    reader = tf.FixedLengthRecordReader(record_bytes=record_length)
    key, record_string = reader.read(filename_queue)
    record_bytes = tf.decode_raw(record_string, tf.uint8)
    
    # Extract label
    image_label = tf.cast(tf.slice(record_bytes, [0],[1]),tf.int32)
    
    # Extract image
    image_extracted = tf.reshape(tf.slice(record_bytes, [1],[image_vec_length]),[num_channels, image_height, image_width])
    
    #Reshape image
    image_uint8image = tf.transpose(image_extracted, [1,2,0])
    reshaped_image = tf.cast(image_uint8image, tf.float32)
    
    #Crop image to 24 by 24
    final_image = tf.image.resize_image_with_crop_or_pad(reshaped_image, crop_width, crop_height)
    # Change the image characteristics to effectively increase the training dataset size
    if distort_images:
        # Randomly flip (1 in 2 chance) the image horizontally along the width
        final_image = tf.image.random_flip_left_right(final_image)
        # Randomly change the image brightness
        final_image = tf.image.random_brightness(final_image, max_delta=63)
        # Randomly change the image contrast
        final_image = tf.image.random_contrast(final_image, lower = 0.2, upper = 1.8)
    #Normalize whitening with standardization
    final_image = tf.image.per_image_standardization(final_image)
    return (final_image, image_label)

# %%
extract_folder = 'cifar-10-batches-bin'
def input_pipeline(batch_size, train_logical = True):
    if train_logical:
        files = [os.path.join(data_dir, extract_folder, 'data_batch_{}.bin'.format(i)) for i in range(1,6)]
    else:
        files = [os.path.join(data_dir, extract_folder, 'test_batch.bin')]
    filename_queue = tf.train.string_input_producer(files)
    image, label = read_cifar_files(filename_queue)
    min_after_dequeue = 1000
    capacity = min_after_dequeue + (3*batch_size)
    example_batch, label_batch = tf.train.shuffle_batch([image,label], batch_size, capacity, min_after_dequeue)
    return (example_batch, label_batch)

# %%
patch_filter_size = 3


def cifar_cnn_model(input_images, batch_size, train_logical = True):
    def truncated_normal_var(name, shape, dtype):
        return (tf.get_variable(name = name, shape = shape, dtype = dtype,\
                                initializer=tf.truncated_normal_initializer(stddev = 0.05)))
    def zero_var(name, shape, dtype):
        return (tf.get_variable(name = name, shape = shape, dtype = dtype,\
                                initializer=tf.constant_initializer(0.0)))
    
    # First Convolutional layer
    with tf.variable_scope('conv1') as scope:
        # Establish and initialize 3 by 3 convolutional kernel (filter) with random values
        # for all 3 channel colors for 64 features
        conv1_kernel = truncated_normal_var(name = 'conv1_kernel', shape = [patch_filter_size,patch_filter_size,3,64],\
                                            dtype = tf.float32)
        
        # Convolve across image with a stride size of one(1)
        conv1 = tf.nn.conv2d(input_images, conv1_kernel, [1,1,1,1], padding = 'SAME')
        
        # Establish and initialize the first layer bias terms with random value 
        conv1_bias = zero_var(name = 'conv1_bias', shape = [64], dtype = tf.float32)
        
        # Add first layer bias terms
        conv1_add_bias = tf.nn.bias_add(conv1, conv1_bias)
        
        # Apply rectified linear unit activation function (ReLU) element-wise
        relu_conv1 = tf.nn.relu(conv1_add_bias)
        
        # Apply max pooling
        max_pool1 = tf.nn.max_pool(relu_conv1, ksize = [1,3,3,1], strides = [1,2,2,1], padding = 'SAME', name = 'pool_layer1')
        
        # Local response normalization
        norm1 = tf.nn.lrn(max_pool1, depth_radius = 5, bias = 2.0, alpha = 1e-3, beta = 0.75, name = 'norm1')
        
    # Second Convolutional layer
    with tf.variable_scope('conv2') as scope:
        # Establish and initialize 3 by 3 convolutional kernel (filter) with random values
        # with previous 64 features and 64 newly created features
        conv2_kernel = truncated_normal_var(name = 'conv2_kernel', shape = [patch_filter_size,patch_filter_size,64,64],\
                                            dtype = tf.float32)
        
        # Convolve across image with a stride size of one(1)
        conv2 = tf.nn.conv2d(norm1, conv2_kernel, [1,1,1,1], padding = 'SAME')
        
        # Establish and initialize the first layer bias terms with random value 
        conv2_bias = zero_var(name = 'conv2_bias', shape = [64], dtype = tf.float32)
        
        # Add first layer bias terms
        conv2_add_bias = tf.nn.bias_add(conv2, conv2_bias)
        
        # Apply rectified linear unit activation function (ReLU) element-wise
        relu_conv2 = tf.nn.relu(conv2_add_bias)
        
        # Apply max pooling
        max_pool2 = tf.nn.max_pool(relu_conv2, ksize = [1,3,3,1], strides = [1,2,2,1], padding = 'SAME', name = 'pool_layer2')
        
        # Local response normalization
        norm2 = tf.nn.lrn(max_pool2, depth_radius = 5, bias = 2.0, alpha = 1e-3, beta = 0.75, name = 'norm2')
        
        # Reshape last convolution layer output for input to fully connected layers
        reshaped_conv_output = tf.reshape(norm2, [batch_size, -1])
        reshaped_conv_output_dim = reshaped_conv_output.get_shape()[1].value
        
        # First Fully Connected Layer
        with tf.variable_scope('full1') as scope:
            # Fully connected layer with 384 output hidden nodes
            # Define number of hidden nodes in first fully connected layer
            hidden_nodes1 = 384
            # Establish and initialize the first fully connected layer weights with random values
            full_weight1 = truncated_normal_var(name = 'full_mult1',shape = [reshaped_conv_output_dim, hidden_nodes1],\
                                                dtype = tf.float32)
            # Establish and initialize the first fully connected layer bias with random values
            full_bias1 = zero_var(name = 'full_bias1',shape = [hidden_nodes1], dtype = tf.float32)
            full_layer1_logits = tf.add(tf.matmul(reshaped_conv_output, full_weight1), full_bias1)
            full_layer1 = tf.nn.relu(full_layer1_logits)
            
            
        # Second Fully Connected Layer
        with tf.variable_scope('full2') as scope:
            # Fully connected layer with 192 output hidden nodes
            # Define number of hidden nodes in first fully connected layer
            hidden_nodes2 = 192
            # Establish and initialize the second fully connected layer weights with random values
            full_weight2 = truncated_normal_var(name = 'full_mult2',shape = [hidden_nodes1, hidden_nodes2],\
                                                dtype = tf.float32)
            # Establish and initialize the first fully connected layer bias with random values
            full_bias2 = zero_var(name = 'full_bias2',shape = [hidden_nodes2], dtype = tf.float32)
            full_layer2_logits = tf.add(tf.matmul(full_layer1, full_weight2), full_bias2)
            full_layer2 = tf.nn.relu(full_layer2_logits)
    
        # Third and Final Fully Connected Layer
        with tf.variable_scope('full3') as scope:
            # Fully connected layer with 10 classification labels
            # Define number of output target in last fully connected layer
            num_targets = 10
            # Establish and initialize the third fully connected layer weights with random values
            full_weight3 = truncated_normal_var(name = 'full_mult3',shape = [hidden_nodes2, num_targets],\
                                                dtype = tf.float32)
            # Establish and initialize the first fully connected layer bias with random values
            full_bias3 = zero_var(name = 'full_bias3',shape = [num_targets], dtype = tf.float32)
            full_layer3_logits = tf.add(tf.matmul(full_layer2, full_weight3), full_bias3)

    return (full_layer3_logits)

# %%
def cifar_loss(logits, targets):
    # Squeeze out extra dimensions and cast targets for integers
    targets = tf.squeeze(tf.cast(targets, tf.int32))
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels = targets, logits = logits)
    cross_entropy_mean = tf.reduce_mean(cross_entropy)
    return (cross_entropy_mean)

# %%
"""Define the training step function"""

# Establish the values for the learning rate function
learning_rate = 0.1
lr_decay = 0.9
num_gens_to_wait = 250

def train_step(loss_value, generation_num):
    # Establish learning rate with exponential decay
    model_learning_rate = tf.train.exponential_decay(learning_rate,\
                                                     generation_num, num_gens_to_wait, lr_decay, staircase=True)
    my_optimizer = tf.train.GradientDescentOptimizer(learning_rate = model_learning_rate)
    train_step = my_optimizer.minimize(loss_value)
    return (train_step)

# %%
def accuracy_of_batch(logits, targets):
    # Squeeze out extra dimensions and cast targets for integers
    targets = tf.squeeze(tf.cast(targets, tf.int32))
    # Determine the predicted values by finding which logit is the greatest
    batch_predictions = tf.cast(tf.argmax(logits,1), tf.int32)
    predicted_correctly = tf.equal(batch_predictions, targets)
    accuracy = tf.reduce_mean(tf.cast(predicted_correctly, tf.float32))
    return (accuracy)

# %%
"""Initial training and test image pipeline functions"""
images, targets = input_pipeline(batch_size, train_logical = True)
test_images, test_targets = input_pipeline(batch_size, train_logical = False)

with tf.variable_scope('model_definition') as scope:
    model_output = cifar_cnn_model(images, batch_size)
    scope.reuse_variables()
    test_output = cifar_cnn_model(test_images, batch_size)

loss = cifar_loss(model_output, targets)
accuracy = accuracy_of_batch(test_output, test_targets)
generation_num = tf.Variable(0, trainable = False)
train_op = train_step(loss, generation_num)

# %%
"""Train and test 2 convolution layer/3 fully connected layer neural network"""
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)
tf.train.start_queue_runners(sess = sess)

train_loss_list = []
test_accuracy_list = []

generations = 20000
output_every = 50
eval_every = 500

# loop to train and test CNN model
for i in range(generations):
    _, loss_value = sess.run([train_op, loss])
    if ((i+1) % output_every == 0):
        train_loss_list.append(loss_value)
        print('Generation {}: Loss = {:.5f}'.format((i+1),loss_value))
    if ((i+1) % eval_every == 0):
        [temp_accuracy] = sess.run([accuracy])
        test_accuracy_list.append(temp_accuracy)
        print('--- Test Accuracy = {:.2f}%'.format(100*temp_accuracy))
# Out:
# Generation 50: Loss = 2.21052
# Generation 100: Loss = 1.91935
# Generation 150: Loss = 1.82570
# Generation 200: Loss = 1.66090
# Generation 250: Loss = 1.56602
# Generation 300: Loss = 1.64866
# Generation 350: Loss = 1.73280
# Generation 400: Loss = 1.69655
# Generation 450: Loss = 1.47424
# Generation 500: Loss = 1.46204
# --- Test Accuracy = 45.31%
# Generation 550: Loss = 1.39565
# Generation 600: Loss = 1.44940
# Generation 650: Loss = 1.50751
# Generation 700: Loss = 1.38659
# Generation 750: Loss = 1.34473
# Generation 800: Loss = 1.64475
# Generation 850: Loss = 1.38174
# Generation 900: Loss = 1.44372
# Generation 950: Loss = 1.45308
# Generation 1000: Loss = 1.12614
# --- Test Accuracy = 50.00%
# Generation 1050: Loss = 1.12176
# Generation 1100: Loss = 1.22427
# Generation 1150: Loss = 1.17860
# Generation 1200: Loss = 1.13623
# Generation 1250: Loss = 1.18104
# Generation 1300: Loss = 1.22290
# Generation 1350: Loss = 1.12261
# Generation 1400: Loss = 1.30153
# Generation 1450: Loss = 1.18898
# Generation 1500: Loss = 1.24920
# --- Test Accuracy = 54.69%
# Generation 1550: Loss = 1.01641
# Generation 1600: Loss = 1.19955
# Generation 1650: Loss = 1.00060
# Generation 1700: Loss = 1.08635
# Generation 1750: Loss = 1.00377
# Generation 1800: Loss = 1.16647
# Generation 1850: Loss = 1.08639
# Generation 1900: Loss = 1.09752
# Generation 1950: Loss = 1.09341
# Generation 2000: Loss = 1.11037
# --- Test Accuracy = 63.28%
# Generation 2050: Loss = 0.79197
# Generation 2100: Loss = 0.85811
# Generation 2150: Loss = 1.08057
# Generation 2200: Loss = 0.73091
# Generation 2250: Loss = 0.85843
# Generation 2300: Loss = 0.70264
# Generation 2350: Loss = 0.95166
# Generation 2400: Loss = 0.92270
# Generation 2450: Loss = 0.90450
# Generation 2500: Loss = 0.94019
# --- Test Accuracy = 62.50%
# Generation 2550: Loss = 0.89756
# Generation 2600: Loss = 0.76136
# Generation 2650: Loss = 0.97745
# Generation 2700: Loss = 1.04908
# Generation 2750: Loss = 0.96455
# Generation 2800: Loss = 0.69493
# Generation 2850: Loss = 0.63004
# Generation 2900: Loss = 0.65724
# Generation 2950: Loss = 0.83101
# Generation 3000: Loss = 0.83068
# --- Test Accuracy = 69.53%
# Generation 3050: Loss = 0.77432
# Generation 3100: Loss = 0.99440
# Generation 3150: Loss = 0.74111
# Generation 3200: Loss = 0.75516
# Generation 3250: Loss = 0.77691
# Generation 3300: Loss = 0.69754
# Generation 3350: Loss = 0.81744
# Generation 3400: Loss = 0.52351
# Generation 3450: Loss = 0.70465
# Generation 3500: Loss = 0.72586
# --- Test Accuracy = 74.22%
# Generation 3550: Loss = 0.78523
# Generation 3600: Loss = 0.67400
# Generation 3650: Loss = 0.80095
# Generation 3700: Loss = 0.64116
# Generation 3750: Loss = 0.76129
# Generation 3800: Loss = 0.75584
# Generation 3850: Loss = 0.52864
# Generation 3900: Loss = 0.72617
# Generation 3950: Loss = 0.47671
# Generation 4000: Loss = 0.52984
# --- Test Accuracy = 82.81%
# Generation 4050: Loss = 0.72935
# Generation 4100: Loss = 0.60962
# Generation 4150: Loss = 0.68790
# Generation 4200: Loss = 0.54286
# Generation 4250: Loss = 0.72826
# Generation 4300: Loss = 0.63505
# Generation 4350: Loss = 0.72746
# Generation 4400: Loss = 0.62300
# Generation 4450: Loss = 0.76442
# Generation 4500: Loss = 0.52895
# --- Test Accuracy = 75.78%
# Generation 4550: Loss = 0.76017
# Generation 4600: Loss = 0.73262
# Generation 4650: Loss = 0.65672
# Generation 4700: Loss = 0.70729
# Generation 4750: Loss = 0.58572
# Generation 4800: Loss = 0.48415
# Generation 4850: Loss = 0.55143
# Generation 4900: Loss = 0.51988
# Generation 4950: Loss = 0.77741
# Generation 5000: Loss = 0.65749
# --- Test Accuracy = 74.22%
# Generation 5050: Loss = 0.65713
# Generation 5100: Loss = 0.55141
# Generation 5150: Loss = 0.58193
# Generation 5200: Loss = 0.47974
# Generation 5250: Loss = 0.48816
# Generation 5300: Loss = 0.43835
# Generation 5350: Loss = 0.57720
# Generation 5400: Loss = 0.56429
# Generation 5450: Loss = 0.51763
# Generation 5500: Loss = 0.46549
# --- Test Accuracy = 66.41%
# Generation 5550: Loss = 0.52265
# Generation 5600: Loss = 0.54649
# Generation 5650: Loss = 0.59877
# Generation 5700: Loss = 0.50928
# Generation 5750: Loss = 0.59898
# Generation 5800: Loss = 0.52414
# Generation 5850: Loss = 0.54381
# Generation 5900: Loss = 0.54998
# Generation 5950: Loss = 0.52397
# Generation 6000: Loss = 0.39695
# --- Test Accuracy = 74.22%
# Generation 6050: Loss = 0.58390
# Generation 6100: Loss = 0.48039
# Generation 6150: Loss = 0.58087
# Generation 6200: Loss = 0.42620
# Generation 6250: Loss = 0.54043
# Generation 6300: Loss = 0.40225
# Generation 6350: Loss = 0.49452
# Generation 6400: Loss = 0.51727
# Generation 6450: Loss = 0.59444
# Generation 6500: Loss = 0.53174
# --- Test Accuracy = 82.81%
# Generation 6550: Loss = 0.47969
# Generation 6600: Loss = 0.52713
# Generation 6650: Loss = 0.45924
# Generation 6700: Loss = 0.48685
# Generation 6750: Loss = 0.52359
# Generation 6800: Loss = 0.30728
# Generation 6850: Loss = 0.43780
# Generation 6900: Loss = 0.60593
# Generation 6950: Loss = 0.48758
# Generation 7000: Loss = 0.37948
# --- Test Accuracy = 77.34%
# Generation 7050: Loss = 0.32247
# Generation 7100: Loss = 0.41069
# Generation 7150: Loss = 0.36524
# Generation 7200: Loss = 0.41493
# Generation 7250: Loss = 0.30411
# Generation 7300: Loss = 0.35363
# Generation 7350: Loss = 0.51426
# Generation 7400: Loss = 0.51982
# Generation 7450: Loss = 0.40758
# Generation 7500: Loss = 0.29200
# --- Test Accuracy = 79.69%
# Generation 7550: Loss = 0.39346
# Generation 7600: Loss = 0.62456
# Generation 7650: Loss = 0.41853
# Generation 7700: Loss = 0.32671
# Generation 7750: Loss = 0.35342
# Generation 7800: Loss = 0.29832
# Generation 7850: Loss = 0.36535
# Generation 7900: Loss = 0.36257
# Generation 7950: Loss = 0.37976
# Generation 8000: Loss = 0.38972
# --- Test Accuracy = 70.31%
# Generation 8050: Loss = 0.48261
# Generation 8100: Loss = 0.35806
# Generation 8150: Loss = 0.43586
# Generation 8200: Loss = 0.44232
# Generation 8250: Loss = 0.35993
# Generation 8300: Loss = 0.31487
# Generation 8350: Loss = 0.40729
# Generation 8400: Loss = 0.28945
# Generation 8450: Loss = 0.31010
# Generation 8500: Loss = 0.40470
# --- Test Accuracy = 79.69%
# Generation 8550: Loss = 0.29136
# Generation 8600: Loss = 0.29591
# Generation 8650: Loss = 0.25987
# Generation 8700: Loss = 0.42192
# Generation 8750: Loss = 0.28365
# Generation 8800: Loss = 0.54405
# Generation 8850: Loss = 0.27794
# Generation 8900: Loss = 0.42961
# Generation 8950: Loss = 0.23278
# Generation 9000: Loss = 0.34808
# --- Test Accuracy = 67.97%
# Generation 9050: Loss = 0.18700
# Generation 9100: Loss = 0.35619
# Generation 9150: Loss = 0.29570
# Generation 9200: Loss = 0.27968
# Generation 9250: Loss = 0.29499
# Generation 9300: Loss = 0.33601
# Generation 9350: Loss = 0.21822
# Generation 9400: Loss = 0.25078
# Generation 9450: Loss = 0.14951
# Generation 9500: Loss = 0.30311
# --- Test Accuracy = 71.09%
# Generation 9550: Loss = 0.31681
# Generation 9600: Loss = 0.29693
# Generation 9650: Loss = 0.28018
# Generation 9700: Loss = 0.20884
# Generation 9750: Loss = 0.29719
# Generation 9800: Loss = 0.24117
# Generation 9850: Loss = 0.35053
# Generation 9900: Loss = 0.16418
# Generation 9950: Loss = 0.22447
# Generation 10000: Loss = 0.24068
# --- Test Accuracy = 72.66%
# Generation 10050: Loss = 0.21022
# Generation 10100: Loss = 0.32786
# Generation 10150: Loss = 0.26021
# Generation 10200: Loss = 0.16624
# Generation 10250: Loss = 0.26651
# Generation 10300: Loss = 0.16230
# Generation 10350: Loss = 0.27279
# Generation 10400: Loss = 0.22050
# Generation 10450: Loss = 0.24975
# Generation 10500: Loss = 0.25374
# --- Test Accuracy = 77.34%
# Generation 10550: Loss = 0.23846
# Generation 10600: Loss = 0.22478
# Generation 10650: Loss = 0.18292
# Generation 10700: Loss = 0.15447
# Generation 10750: Loss = 0.21719
# Generation 10800: Loss = 0.25361
# Generation 10850: Loss = 0.23992
# Generation 10900: Loss = 0.13920
# Generation 10950: Loss = 0.23132
# Generation 11000: Loss = 0.21597
# --- Test Accuracy = 79.69%
# Generation 11050: Loss = 0.19695
# Generation 11100: Loss = 0.28210
# Generation 11150: Loss = 0.15855
# Generation 11200: Loss = 0.18453
# Generation 11250: Loss = 0.22028
# Generation 11300: Loss = 0.23703
# Generation 11350: Loss = 0.12112
# Generation 11400: Loss = 0.17964
# Generation 11450: Loss = 0.21331
# Generation 11500: Loss = 0.20342
# --- Test Accuracy = 77.34%
# Generation 11550: Loss = 0.12104
# Generation 11600: Loss = 0.19832
# Generation 11650: Loss = 0.18645
# Generation 11700: Loss = 0.28047
# Generation 11750: Loss = 0.21714
# Generation 11800: Loss = 0.17250
# Generation 11850: Loss = 0.23800
# Generation 11900: Loss = 0.25389
# Generation 11950: Loss = 0.22268
# Generation 12000: Loss = 0.11362
# --- Test Accuracy = 71.88%
# Generation 12050: Loss = 0.13934
# Generation 12100: Loss = 0.14836
# Generation 12150: Loss = 0.09640
# Generation 12200: Loss = 0.06372
# Generation 12250: Loss = 0.18502
# Generation 12300: Loss = 0.17470
# Generation 12350: Loss = 0.25842
# Generation 12400: Loss = 0.18102
# Generation 12450: Loss = 0.10055
# Generation 12500: Loss = 0.06875
# --- Test Accuracy = 71.88%
# Generation 12550: Loss = 0.07669
# Generation 12600: Loss = 0.16684
# Generation 12650: Loss = 0.17401
# Generation 12700: Loss = 0.05331
# Generation 12750: Loss = 0.16286
# Generation 12800: Loss = 0.20943
# Generation 12850: Loss = 0.10481
# Generation 12900: Loss = 0.16588
# Generation 12950: Loss = 0.07238
# Generation 13000: Loss = 0.13242
# --- Test Accuracy = 79.69%
# Generation 13050: Loss = 0.23821
# Generation 13100: Loss = 0.18970
# Generation 13150: Loss = 0.17769
# Generation 13200: Loss = 0.12762
# Generation 13250: Loss = 0.10047
# Generation 13300: Loss = 0.22577
# Generation 13350: Loss = 0.11392
# Generation 13400: Loss = 0.13652
# Generation 13450: Loss = 0.10138
# Generation 13500: Loss = 0.10006
# --- Test Accuracy = 77.34%
# Generation 13550: Loss = 0.10895
# Generation 13600: Loss = 0.13844
# Generation 13650: Loss = 0.15847
# Generation 13700: Loss = 0.05587
# Generation 13750: Loss = 0.11923
# Generation 13800: Loss = 0.16849
# Generation 13850: Loss = 0.15102
# Generation 13900: Loss = 0.07087
# Generation 13950: Loss = 0.15416
# Generation 14000: Loss = 0.12921
# --- Test Accuracy = 67.19%
# Generation 14050: Loss = 0.25363
# Generation 14100: Loss = 0.09027
# Generation 14150: Loss = 0.13538
# Generation 14200: Loss = 0.09030
# Generation 14250: Loss = 0.30361
# Generation 14300: Loss = 0.07437
# Generation 14350: Loss = 0.11066
# Generation 14400: Loss = 0.22324
# Generation 14450: Loss = 0.15316
# Generation 14500: Loss = 0.05475
# --- Test Accuracy = 73.44%
# Generation 14550: Loss = 0.05889
# Generation 14600: Loss = 0.06473
# Generation 14650: Loss = 0.13575
# Generation 14700: Loss = 0.07624
# Generation 14750: Loss = 0.06336
# Generation 14800: Loss = 0.12262
# Generation 14850: Loss = 0.13501
# Generation 14900: Loss = 0.11003
# Generation 14950: Loss = 0.05121
# Generation 15000: Loss = 0.09476
# --- Test Accuracy = 71.88%
# Generation 15050: Loss = 0.16239
# Generation 15100: Loss = 0.07997
# Generation 15150: Loss = 0.07460
# Generation 15200: Loss = 0.21235
# Generation 15250: Loss = 0.10135
# Generation 15300: Loss = 0.10277
# Generation 15350: Loss = 0.06401
# Generation 15400: Loss = 0.07038
# Generation 15450: Loss = 0.08816
# Generation 15500: Loss = 0.12324
# --- Test Accuracy = 73.44%
# Generation 15550: Loss = 0.04569
# Generation 15600: Loss = 0.14637
# Generation 15650: Loss = 0.04328
# Generation 15700: Loss = 0.03699
# Generation 15750: Loss = 0.04672
# Generation 15800: Loss = 0.07583
# Generation 15850: Loss = 0.21141
# Generation 15900: Loss = 0.09298
# Generation 15950: Loss = 0.07350
# Generation 16000: Loss = 0.03687
# --- Test Accuracy = 74.22%
# Generation 16050: Loss = 0.11380
# Generation 16100: Loss = 0.09826
# Generation 16150: Loss = 0.05985
# Generation 16200: Loss = 0.24185
# Generation 16250: Loss = 0.12783
# Generation 16300: Loss = 0.03661
# Generation 16350: Loss = 0.07563
# Generation 16400: Loss = 0.05291
# Generation 16450: Loss = 0.05947
# Generation 16500: Loss = 0.03084
# --- Test Accuracy = 76.56%
# Generation 16550: Loss = 0.12636
# Generation 16600: Loss = 0.03614
# Generation 16650: Loss = 0.06373
# Generation 16700: Loss = 0.06487
# Generation 16750: Loss = 0.03218
# Generation 16800: Loss = 0.09272
# Generation 16850: Loss = 0.03811
# Generation 16900: Loss = 0.04879
# Generation 16950: Loss = 0.03524
# Generation 17000: Loss = 0.11275
# --- Test Accuracy = 76.56%
# Generation 17050: Loss = 0.09424
# Generation 17100: Loss = 0.04923
# Generation 17150: Loss = 0.10076
# Generation 17200: Loss = 0.05634
# Generation 17250: Loss = 0.07988
# Generation 17300: Loss = 0.05260
# Generation 17350: Loss = 0.08009
# Generation 17400: Loss = 0.07178
# Generation 17450: Loss = 0.13258
# Generation 17500: Loss = 0.05054
# --- Test Accuracy = 78.12%
# Generation 17550: Loss = 0.07186
# Generation 17600: Loss = 0.05858
# Generation 17650: Loss = 0.06131
# Generation 17700: Loss = 0.05535
# Generation 17750: Loss = 0.08849
# Generation 17800: Loss = 0.02140
# Generation 17850: Loss = 0.13396
# Generation 17900: Loss = 0.11545
# Generation 17950: Loss = 0.07445
# Generation 18000: Loss = 0.08952
# --- Test Accuracy = 73.44%
# Generation 18050: Loss = 0.08625
# Generation 18100: Loss = 0.03267
# Generation 18150: Loss = 0.06597
# Generation 18200: Loss = 0.04062
# Generation 18250: Loss = 0.05159
# Generation 18300: Loss = 0.09860
# Generation 18350: Loss = 0.03967
# Generation 18400: Loss = 0.05051
# Generation 18450: Loss = 0.01925
# Generation 18500: Loss = 0.05881
# --- Test Accuracy = 67.19%
# Generation 18550: Loss = 0.07028
# Generation 18600: Loss = 0.03738
# Generation 18650: Loss = 0.02944
# Generation 18700: Loss = 0.01715
# Generation 18750: Loss = 0.04609
# Generation 18800: Loss = 0.06483
# Generation 18850: Loss = 0.03044
# Generation 18900: Loss = 0.06367
# Generation 18950: Loss = 0.12036
# Generation 19000: Loss = 0.04660
# --- Test Accuracy = 74.22%
# Generation 19050: Loss = 0.05457
# Generation 19100: Loss = 0.05035
# Generation 19150: Loss = 0.07602
# Generation 19200: Loss = 0.11558
# Generation 19250: Loss = 0.03208
# Generation 19300: Loss = 0.10979
# Generation 19350: Loss = 0.07089
# Generation 19400: Loss = 0.12003
# Generation 19450: Loss = 0.09748
# Generation 19500: Loss = 0.09651
# --- Test Accuracy = 68.75%
# Generation 19550: Loss = 0.02793
# Generation 19600: Loss = 0.03477
# Generation 19650: Loss = 0.02607
# Generation 19700: Loss = 0.03872
# Generation 19750: Loss = 0.03892
# Generation 19800: Loss = 0.01733
# Generation 19850: Loss = 0.04285
# Generation 19900: Loss = 0.05047
# Generation 19950: Loss = 0.04026
# Generation 20000: Loss = 0.16489
# --- Test Accuracy = 71.09%

# %%
"""Visualize model loss and performance"""
eval_indices = list(range(0, generations, eval_every))
output_indices = list(range(0, generations, output_every))
plt.plot(output_indices, train_loss_list, 'k-')
plt.title('Softmax Loss per Generation')
plt.xlabel('Generations')
plt.ylabel('Softmax Loss')
plt.show()
plt.plot(eval_indices, test_accuracy_list, 'k-')
plt.title('Test Accuracy per Generation')
plt.xlabel('Generations')
plt.ylabel('Accuracy')
plt.show()

# %%
"""Visualize model loss and performance"""
eval_indices = list(range(0, generations, eval_every))
output_indices = list(range(0, generations, output_every))
plt.plot(output_indices, train_loss_list, 'k-')
plt.title('Softmax Loss per Generation')
plt.xlabel('Generations')
plt.ylabel('Softmax Loss')
plt.show()
plt.plot(eval_indices, test_accuracy_list, 'k-')
plt.title('Test Accuracy per Generation')
plt.xlabel('Generations')
plt.ylabel('Accuracy')
plt.show()
